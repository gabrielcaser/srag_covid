# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
import pandas as pd
import glob
pd.set_option('display.max_rows', None)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Baixando bases e salvando em .csv

# %% [markdown]
# - 2009 a 2011
#   - O dicionário das bases de 2009 a 2011 é bem diferente dos demais. Então fui olhar a base para ver se ela também era diferente. Como você pode ver abaixo, o dicionário está bem diferente da base (parece que cortaram umas 2 páginas do pdf).
#   - O lado bom é que, aparentemente, as bases de 2009 a 2011 estão bem parecidas com as seguintes e o problema parece estar no pdf do dicionário de 2009-2011 (https://d26692udehoye.cloudfront.net/SRAG/2009-2012/dicionario_de_dados_influenza_pandemica_antigo.pdf)

# %%
df_2009 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2009-2012/INFLUD09.csv', sep = ';')
path = '/content/drive/My Drive/br_ms_sinan/input/sivep_2009.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2009.to_csv(f)

# %%
df_2010 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2009-2012/INFLUD10.csv', sep = ';')
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2010.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2010.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (41,73,79,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2011 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2009-2012/INFLUD11.csv', sep = ';')
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2011.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2011.to_csv(f)

# %% [markdown]
# - 2012

# %%
df_2012 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2009-2012/INFLUD12.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2012.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2012.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (72,74) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# - 2013 a 2018

# %%
df_2013 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2013-2018/INFLUD13.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2013.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2013.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (74,75) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2014 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2013-2018/INFLUD14.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2014.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2014.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (74,75) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2015 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2013-2018/INFLUD15.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2015.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2015.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (74) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2016 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2013-2018/INFLUD16.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2016.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2016.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (74) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2017 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2013-2018/INFLUD17.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2017.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2017.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (75) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2018 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2013-2018/INFLUD18.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2018.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2018.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (74) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2019_teste = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2019/INFLUD19.csv', sep = ';', encoding = "ISO-8859-1")
# Out:
# <ipython-input-22-acd57021d678>:1: DtypeWarning: Columns (96,104,106,131) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2019_teste = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2019/INFLUD19.csv', sep = ';', encoding = "ISO-8859-1")

# %% [markdown]
# - 2019

# %%
df_2019 = pd.read_csv('https://d26692udehoye.cloudfront.net/SRAG/2019/INFLUD19.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2019.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2019.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (96,104,106,131) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# - 2020

# %%
df_2020 = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2020/INFLUD20-22-08-2022.csv', sep = ';', encoding = "ISO-8859-1")
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2020.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2020.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (15,59,61,62,63,91,93,105,114,116,117,118,120,122,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# - 2021 e 2022

# %%
df_2021 = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2021/INFLUD21-22-08-2022.csv', sep = ';')
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2021.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2021.to_csv(f)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (15,59,61,62,63,91,93,105,107,114,116,117,118,122,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_2022 = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2022/INFLUD22-22-08-2022.csv', sep = ';')
path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2022.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df_2022.to_csv(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2e548090a504> in <module>
# ----> 1 df_2022 = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2022/INFLUD22-22-08-2022.csv', sep = ';')
#       2 path = '/content/gdrive/My Drive/br_ms_sinan/input/sivep_2022.csv'
#       3 with open(path, 'w', encoding = 'utf-8-sig') as f:
#       4   df_2022.to_csv(f)
#
# NameError: name 'pd' is not defined
